# %%
import pandas as pd

# %%
p1 = {"name":"abc", "age":"23", "address":"pune"}
p2 = {"name":"xyz", "age":"25", "address":"mumbai"}
p3 = {"name":"pqr", "age":"30", "address":"delhi"}

s1 = pd.Series(p1)
s2 = pd.Series(p2)
s3 = pd.Series(p3)

print(s1)
print(s2)
print(s3)

print(s1['name'])
# Out:
# name        abc
# age          23
# address    pune
# dtype: object
# name          xyz
# age            25
# address    mumbai
# dtype: object
# name         pqr
# age           30
# address    delhi
# dtype: object
# abc

# %%
df = pd.DataFrame([s1, s2, s3])
print(df)
# Out:
#   name age address
# 0  abc  23    pune
# 1  xyz  25  mumbai
# 2  pqr  30   delhi
